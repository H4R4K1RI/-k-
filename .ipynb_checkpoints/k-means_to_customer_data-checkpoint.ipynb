# %%
import pandas as pd
customers = pd.read_csv('Data/customers.csv')
customers.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# %matplotlib inline
import matplotlib.pyplot as рlt
import seaborn as sns
sns.set() 
points = customers.iloc[:, 3:5].values
x = points[:, 0]
y = points[:, 1]
plt.scatter(x, y, s=50, alpha=0.7)
рlt.xlabel('Ежегодный доход,$')
рlt.ylabel('Рейтинг расходов')
# Out:
# Text(0, 0.5, 'Рейтинг расходов')

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 5, random_state = 0)
kmeans.fit(points)
predicted_cluster_indexes = kmeans.predict(points)

plt.scatter(x, y, c = predicted_cluster_indexes, s = 50, alpha = 0.7, cmap = 'viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c = 'red', s = 100)
рlt.xlabel('Ежегодный доход,$')
рlt.ylabel('Рейтинг расходов')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c = 'red', s = 100)

# %%
df = customers.copy()
df['Cluster'] = kmeans.predict(points)
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        3
# 1        4
# 2        3
# 3        4
# 4        3

# %%
import numpy as np

cluster = kmeans.predict(np.array([[120,20]]))[0]
clustered_df = df[df['Cluster'] == cluster]
clustered_df['CustomerID'].values
# Out:
# array([125, 129, 131, 135, 137, 139, 141, 145, 147, 149, 151, 153, 155,
#        157, 159, 161, 163, 165, 167, 169, 171, 173, 175, 177, 179, 181,
#        183, 185, 187, 189, 191, 193, 195, 197, 199], dtype=int64)
